# %% [markdown]
# <a href="https://colab.research.google.com/github/SIDDH4RTH245/movie-recommender-system/blob/main/notebooks/04_model_saving.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Load cleaned movie data
df = pd.read_csv("movies_cleaned.csv")

# Create vectors
cv = CountVectorizer(stop_words="english")

vectors = cv.fit_transform(df["tags"]).toarray()

# Create similarity matrix
similarity = cosine_similarity(vectors)

print(similarity.shape)
# Out:
# (9742, 9742)

# %%
import os
import pickle

os.makedirs("../model", exist_ok=True)

pickle.dump(similarity, open("similarity.pkl","wb"))
pickle.dump(df, open("movies.pkl","wb"))

print("Saved successfully!")
# Out:
# Saved successfully!
